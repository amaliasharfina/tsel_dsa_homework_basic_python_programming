# %% [markdown]
# # Soal dan Jawaban Homework DSA (Basic Python Programming)
# ## Amalia Sharfina Sulwan - 95079

# %% [markdown]
# Import library dan datasets

# %%
import pandas as pd
import numpy as np


googleplay=pd.read_csv('D:\DIIS - Mobility Insight\DS Academy\Day 3_Python\google-play-store-apps\googleplaystore.csv',encoding='latin1')
googleplay.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ### 1. In the dataset of googleplaystore.csv, it consists of  10841 rows and 13 columns.

# %%
print(googleplay.shape)
# Out:
# (10841, 13)

# %% [markdown]
# ### 2. How many unique apps categories reflected in the dataset?

# %%
googleplay["App"].value_counts()
# Out:
# ROBLOX                                                       9
# CBS Sports App - Scores, News, Stats & Watch Live            8
# Candy Crush Saga                                             7
# ESPN                                                         7
# Duolingo: Learn Languages Free                               7
# 8 Ball Pool                                                  7
# Sniper 3D Gun Shooter: Free Shooting Games - FPS             6
# Zombie Catchers                                              6
# Helix Jump                                                   6
# Bowmasters                                                   6
# slither.io                                                   6
# Bubble Shooter                                               6
# Temple Run 2                                                 6
# Subway Surfers                                               6
# Nick                                                         6
# ...

# %% [markdown]
# ### 3. How many unique genres according to the dataset?

# %%
googleplay["Genres"].value_counts()
# Out:
# Tools                                  842
# Entertainment                          623
# Education                              549
# Medical                                463
# Business                               460
# Productivity                           424
# Sports                                 398
# Personalization                        392
# Communication                          387
# Lifestyle                              381
# Finance                                366
# Action                                 365
# Health & Fitness                       341
# Photography                            335
# Social                                 295
# News & Magazines                       283
# Shopping                               260
# Travel & Local                         257
# Dating                                 234
# Books & Reference                      231
# Arcade                                 220
# Simulation                             200
# ...

# %% [markdown]
# ### 4. Which code is appropriate to drop duplicate values in 'App' column and remove its rows in Python?

# %%
googleplay.drop_duplicates(subset='App', inplace=True)
googleplay["App"].value_counts()
# Out:
# EZ game screen recorder with audio 1080P              1
# Baldur's Gate: Enhanced Edition                       1
# Q-slope                                               1
# CestovnÃ© poriadky CP                                 1
# My Child from eDziecko.pl                             1
# DRAGON QUEST V                                        1
# Free Resume App                                       1
# Barista Coffee Dictionary A-Z                         1
# Mermaids                                              1
# Co-Dependents Anonymous                               1
# Yoga Studio: Mind & Body                              1
# Animal Jam - Play Wild!                               1
# Ninja FN Button                                       1
# codeEazy - C/C++/JAVA                                 1
# Redfin Real Estate                                    1
# Master of Eternity(MOE)                               1
# Tickets + PDA 2018 Exam                               1
# ...

# %% [markdown]
# ### 5. Upon removing duplicate of App column, please run the following code to remove a row that contain 'Free' value at the 'Installs' column. You can check first with this code:

# %%
googleplay[googleplay['Installs']=='Free']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# To remove that specific row:

# %%
googleplay=googleplay[googleplay['Installs'] != 'Free']

# %% [markdown]
# If you want to remove character '+' in column 'Installs', you can run the following codes in Python.

# %%
googleplay['Installs'] = googleplay['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)
googleplay["Installs"].value_counts()
# Out:
# 1,000,000        1579
# 10,000,000       1252
# 100,000          1169
# 10,000           1054
# 1,000             907
# 5,000,000         752
# 100               719
# 500,000           539
# 50,000            479
# 5,000             477
# 100,000,000       409
# 10                386
# 500               330
# 50,000,000        289
# 50                205
# 5                  82
# 500,000,000        72
# 1                  67
# 1,000,000,000      58
# 0                  15
# Name: Installs, dtype: int64

# %% [markdown]
# Then, if you want to remove character ',' in column 'Installs', you can run the following codes in Python.

# %%
googleplay['Installs'] = googleplay['Installs'].apply(lambda x: x.replace(',','')if ',' in str(x) else x)
googleplay["Installs"].value_counts()
# Out:
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           907
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# Name: Installs, dtype: int64

# %% [markdown]
# ### 6. If you want to convert data type of 'Installs' columns into integer, you can run the following code.

# %%
googleplay['Installs']=googleplay['Installs'].astype(int)
print(googleplay.dtypes)
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs            int32
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# ### 7. Match Apps and Category based on provided dataset!

# %%
googleplay[['App', 'Category']][(googleplay.App == 'Pinterest')|(googleplay.App == 'File Commander - File Manager/Explorer')|(googleplay.App == 'DU Battery Saver - Battery Charger & Battery Life')|(googleplay.App == 'Subway Surfers')|(googleplay.App == 'FIFA Soccer')|(googleplay.App == 'Dropbox')|(googleplay.App == 'WhatsApp Messenger')|(googleplay.App == 'Flipboard: News For Our Time')]
# Out:
#                                                      App            Category
# 336                                   WhatsApp Messenger       COMMUNICATION
# 381                                   WhatsApp Messenger       COMMUNICATION
# 1654                                      Subway Surfers                GAME
# 1700                                      Subway Surfers                GAME
# 1750                                      Subway Surfers                GAME
# 1872                                      Subway Surfers                GAME
# 1917                                      Subway Surfers                GAME
# 2552                                           Pinterest              SOCIAL
# 2612                                           Pinterest              SOCIAL
# 3473                                             Dropbox        PRODUCTIVITY
# 3569                                             Dropbox        PRODUCTIVITY
# ...

# %% [markdown]
# ### 8. The following applications were installed by more than 1 billion users, EXCEPT

# %%
googleplay[['App', 'Installs']][(googleplay.App == 'Facebook')|(googleplay.App == 'WhatsApp Messenger')|(googleplay.App == 'Skype - free IM & video calls')|(googleplay.App == 'Google Duo - High Quality Video Calls')]
# Out:
#                                         App    Installs
# 336                      WhatsApp Messenger  1000000000
# 371   Google Duo - High Quality Video Calls   500000000
# 381                      WhatsApp Messenger  1000000000
# 391           Skype - free IM & video calls  1000000000
# 468           Skype - free IM & video calls  1000000000
# 2544                               Facebook  1000000000
# 3904                     WhatsApp Messenger  1000000000
# 3943                               Facebook  1000000000
# 4039  Google Duo - High Quality Video Calls   500000000
# 4234          Skype - free IM & video calls  1000000000

# %% [markdown]
# ### 9. Arrange top COMMUNICATION category apps from the highest number of reviews to the lowest!

# %%
comm_app=googleplay[(googleplay.Category=='COMMUNICATION')&(googleplay.App=='Viber Messenger')|(googleplay.App=='LINE: Free Calls & Messages')|(googleplay.App=='Skype - free IM & video calls')|(googleplay.App=='BBM - Free Calls & Messages')|(googleplay.App=='WhatsApp Messenger')]
comm_app.sort_values(by=['Rating'],ascending=False)
# Out:
#                                 App       Category  Rating   Reviews  \
# 336              WhatsApp Messenger  COMMUNICATION     4.4  69119316
# 381              WhatsApp Messenger  COMMUNICATION     4.4  69119316
# 3904             WhatsApp Messenger  COMMUNICATION     4.4  69109672
# 342                 Viber Messenger  COMMUNICATION     4.3  11334799
# 385                 Viber Messenger  COMMUNICATION     4.3  11334973
# 406     BBM - Free Calls & Messages  COMMUNICATION     4.3  12842860
# 431                 Viber Messenger  COMMUNICATION     4.3  11334973
# 467                 Viber Messenger  COMMUNICATION     4.3  11335255
# 4676                Viber Messenger  COMMUNICATION     4.3  11335481
# 6449    BBM - Free Calls & Messages  COMMUNICATION     4.3  12843436
# 403     LINE: Free Calls & Messages  COMMUNICATION     4.2  10790289
# 474     LINE: Free Calls & Messages  COMMUNICATION     4.2  10790289
# 4122    LINE: Free Calls & Messages  COMMUNICATION     4.2  10790092
# ...

# %% [markdown]
# ### 10. Arrange top 3 game category apps based on number of installed and rating!

# %%
game_app=googleplay[(googleplay.Category=='GAME')&(googleplay.App=='Subway Surfers')|(googleplay.App=='Candy Crush Saga')|(googleplay.App=='Temple Run 2')|(googleplay.App=='My Talking Tom')]
game_app.sort_values(by=['Rating','Installs'],ascending=False)
# Out:
#                    App Category  Rating   Reviews                Size  \
# 1654    Subway Surfers     GAME     4.5  27722264                 76M
# 1700    Subway Surfers     GAME     4.5  27723193                 76M
# 1750    Subway Surfers     GAME     4.5  27724094                 76M
# 1872    Subway Surfers     GAME     4.5  27725352                 76M
# 1917    Subway Surfers     GAME     4.5  27725352                 76M
# 3896    Subway Surfers     GAME     4.5  27711703                 76M
# 1722    My Talking Tom     GAME     4.5  14891223  Varies with device
# 1908    My Talking Tom     GAME     4.5  14892469  Varies with device
# 3888    My Talking Tom   FAMILY     4.5  14885236  Varies with device
# 1655  Candy Crush Saga     GAME     4.4  22426677                 74M
# 1705  Candy Crush Saga     GAME     4.4  22428456                 74M
# 1751  Candy Crush Saga     GAME     4.4  22428456                 74M
# ...
